# %% [markdown]
# **Heart Attack Prediction using Machine Learning**

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Importing the dataset
for dirname, _, filenames in os.walk('/Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/.DS_Store
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/heart_attack_prediction_dataset.csv
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/Heart_Attack_Prediction.ipynb
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/.gitattributes
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/.git/config
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/.git/HEAD
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/.git/description
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/.git/index
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/.git/COMMIT_EDITMSG
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/.git/FETCH_HEAD
# /Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/.git/objects/92/22d01d04359fbef498a4d58c49921caa75d7aa
# ...

# %% [markdown]
# **Loading the Dataset**

# %%
df = pd.read_csv('/Users/aaravgoyal/Downloads/GitHub/HeartAttackPrediction_ML/heart_attack_prediction_dataset.csv')
df
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       BMW7812   67    Male          208         158/88          72
# 1       CZE1114   21    Male          389         165/93          98
# 2       BNI9906   21  Female          324         174/99          72
# 3       JLN3497   84    Male          383        163/100          73
# 4       GFO8847   66    Male          318          91/88          93
# ...         ...  ...     ...          ...            ...         ...
# 8758    MSV9918   60    Male          121          94/76          61
# 8759    QSV6764   28  Female          120        157/102          73
# 8760    XKA5925   47    Male          250         161/75         105
# 8761    EPE6801   36    Male          178         119/67          60
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 0            0               0        1        0  ...
# ...

# %% [markdown]
# **Initial Analysis on the Dataset**

# %%
df.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
# 2               0        0        0  ...                 9.463426  235282
# 3               1        1        0  ...                 7.648981  125640
# 4               1        1        1  ...                 1.514821  160555
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %%
print("Shape of the dataset: ", df.shape)
# Out:
# Shape of the dataset:  (8763, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %% [markdown]
# **Analysis of Outputs**

# %% [markdown]
# **Examining the Missing Values**

# %%
df.isnull().sum()
# Out:
# Patient ID                         0
# Age                                0
# Sex                                0
# Cholesterol                        0
# Blood Pressure                     0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# Income                             0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# ...

# %%
isnull_number = []
for i in df.columns:
    isnull_number.append(df[i].isnull().sum())

pd.DataFrame(isnull_number, index = df.columns, columns = ['Total Missing Values'])
# Out:
#                                  Total Missing Values
# Patient ID                                          0
# Age                                                 0
# Sex                                                 0
# Cholesterol                                         0
# Blood Pressure                                      0
# Heart Rate                                          0
# Diabetes                                            0
# Family History                                      0
# Smoking                                             0
# Obesity                                             0
# Alcohol Consumption                                 0
# Exercise Hours Per Week                             0
# Diet                                                0
# Previous Heart Problems                             0
# Medication Use                                      0
# Stress Level                                        0
# ...
